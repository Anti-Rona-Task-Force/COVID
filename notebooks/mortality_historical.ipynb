# %% [markdown]
# # Exploring Data
# Historical mortality rates by state.
#
# [CDC Data](https://data.cdc.gov/NCHS/Weekly-counts-of-death-by-jurisdiction-and-cause-o/u6jv-9ijr) (Updated Oct. 21, 2020)
#
# ----
#
# Use this notebook to explore and prepare data

# %%
import os
import numpy as np
import pandas as pd

# %%
# Historical deaths by jurisiction. (State)
df = pd.read_csv('../data/raw/Weekly_counts_of_death_by_jurisdiction_and_cause_of_death.csv')

# %%
df.head()
# Out:
#   Jurisdiction Week Ending Date State Abbreviation  Year  Week  \
# 0      Alabama       2015-01-10                 AL  2015     1
# 1      Alabama       2015-01-10                 AL  2015     1
# 2      Alabama       2016-01-09                 AL  2016     1
# 3      Alabama       2016-01-09                 AL  2016     1
# 4      Alabama       2017-01-07                 AL  2017     1
#
#                       Cause Group  Number of Deaths  \
# 0  Alzheimer disease and dementia             120.0
# 1  Alzheimer disease and dementia             120.0
# 2  Alzheimer disease and dementia              76.0
# 3  Alzheimer disease and dementia              76.0
# 4  Alzheimer disease and dementia              96.0
#
#                    Cause Subgroup Time Period Suppress Note  \
# 0  Alzheimer disease and dementia   2015-2019      NaN  NaN
# 1  Alzheimer disease and dementia   2015-2019      NaN  NaN
# 2  Alzheimer disease and dementia   2015-2019      NaN  NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314408 entries, 0 to 314407
# Data columns (total 15 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   Jurisdiction                               314408 non-null  object
#  1   Week Ending Date                           314408 non-null  object
#  2   State Abbreviation                         314408 non-null  object
#  3   Year                                       314408 non-null  int64
#  4   Week                                       314408 non-null  int64
#  5   Cause Group                                314408 non-null  object
#  6   Number of Deaths                           314405 non-null  float64
#  7   Cause Subgroup                             314408 non-null  object
#  8   Time Period                                314408 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Year           Week  Number of Deaths  \
# count  314408.000000  314408.000000     314405.000000
# mean     2017.390073      25.359457        157.290721
# std         1.656097      14.872981        681.482566
# min      2015.000000       1.000000         11.000000
# 25%      2016.000000      12.000000         23.000000
# 50%      2017.000000      25.000000         44.000000
# 75%      2019.000000      38.000000         94.000000
# max      2020.000000      52.000000      12433.000000
#
#        Average Number of Deaths in Time Period  \
# count                             314408.00000
# mean                                 157.29122
# std                                  681.11835
# min                                   11.00000
# 25%                                   24.00000
# 50%                                   44.00000
# 75%                                   94.00000
# max                                12046.00000
#
# ...
