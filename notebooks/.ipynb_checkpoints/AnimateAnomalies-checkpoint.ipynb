# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')
import os
import pandas as pd
import os.path
from os import path
import datetime
import plotly.express as px
#from fbprophet import Prophet

# %%
from urllib.request import urlopen
import json

with open('../data/raw/geojson-counties-fips.json') as json_file:
    counties = json.load(json_file)

# %%
import plotly.express as px

# %%
import csv
countyAndState_ToFips = {}

with open('../data/raw/CountyToFips.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            county = row[2]
            indexOfP = county.find("Parish")
            if indexOfP != -1:
                county = county[:indexOfP] + "County"
                #print(county)
            state = row[1]
            print(state)
            countyAndState_ToFips[(county, row[1])] = row[0]
            line_count += 1
    print(f'Processed {line_count} lines.')
print(countyAndState_ToFips)
# Out:
# Column names are FIPS, STNAME, CTYNAME
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Iowa
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Kansas
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Illinois
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# Indiana
# New Mexico
# New Mexico
# Processed 3144 lines.
# {('Fulton County', 'Indiana'): '18049', ('Gibson County', 'Indiana'): '18051', ('Grant County', 'Indiana'): '18053', ('Greene County', 'Indiana'): '18055', ('Hamilton County', 'Indiana'): '18057', ('Hancock County', 'Indiana'): '18059', ('Harrison County', 'Indiana'): '18061', ('Hendricks County', 'Indiana'): '18063', ('Henry County', 'Indiana'): '18065', ('Howard County', 'Indiana'): '18067', ('Huntington County', 'Indiana'): '18069', ('Jackson County', 'Indiana'): '18071', ('Jasper County', 'Indiana'): '18073', ('Jay County', 'Indiana'): '18075', ('Jefferson County', 'Indiana'): '18077', ('Jennings County', 'Indiana'): '18079', ('Johnson County', 'Indiana'): '18081', ('Knox County', 'Indiana'): '18083', ('Kosciusko County', 'Indiana'): '18085', ('LaGrange County', 'Indiana'): '18087', ('Lake County', 'Indiana'): '18089', ('LaPorte County', 'Indiana'): '18091', ('Lawrence County', 'Indiana'): '18093', ('Madison County', 'Indiana'): '18095', ('Marion County', 'Indiana'): '18097', ('Marshall County', 'Indiana'): '18099', ('Martin County', 'Indiana'): '18101', ('Miami County', 'Indiana'): '18103', ('Monroe County', 'Indiana'): '18105', ('Montgomery County', 'Indiana'): '18107', ('Morgan County', 'Indiana'): '18109', ('Newton County', 'Indiana'): '18111', ('Noble County', 'Indiana'): '18113', ('Ohio County', 'Indiana'): '18115', ('Orange County', 'Indiana'): '18117', ('Owen County', 'Indiana'): '18119', ('Parke County', 'Indiana'): '18121', ('Perry County', 'Indiana'): '18123', ('Pike County', 'Indiana'): '18125', ('Porter County', 'Indiana'): '18127', ('Posey County', 'Indiana'): '18129', ('Pulaski County', 'Indiana'): '18131', ('Putnam County', 'Indiana'): '18133', ('Randolph County', 'Indiana'): '18135', ('Ripley County', 'Indiana'): '18137', ('Rush County', 'Indiana'): '18139', ('St. Joseph County', 'Indiana'): '18141', ('Scott County', 'Indiana'): '18143', ('Shelby County', 'Indiana'): '18145', ('Spencer County', 'Indiana'): '18147', ('Starke County', 'Indiana'): '18149', ('Steuben County', 'Indiana'): '18151', ('Sullivan County', 'Indiana'): '18153', ('Switzerland County', 'Indiana'): '18155', ('Tippecanoe County', 'Indiana'): '18157', ('Tipton County', 'Indiana'): '18159', ('Union County', 'Indiana'): '18161', ('Vanderburgh County', 'Indiana'): '18163', ('Vermillion County', 'Indiana'): '18165', ('Vigo County', 'Indiana'): '18167', ('Wabash County', 'Indiana'): '18169', ('Warren County', 'Indiana'): '18171', ('Warrick County', 'Indiana'): '18173', ('Washington County', 'Indiana'): '18175', ('Wayne County', 'Indiana'): '18177', ('Wells County', 'Indiana'): '18179', ('White County', 'Indiana'): '18181', ('Whitley County', 'Indiana'): '18183', ('Adair County', 'Iowa'): '19001', ('Adams County', 'Iowa'): '19003', ('Allamakee County', 'Iowa'): '19005', ('Appanoose County', 'Iowa'): '19007', ('Audubon County', 'Iowa'): '19009', ('Benton County', 'Iowa'): '19011', ('Black Hawk County', 'Iowa'): '19013', ('Boone County', 'Iowa'): '19015', ('Bremer County', 'Iowa'): '19017', ('Buchanan County', 'Iowa'): '19019', ('Buena Vista County', 'Iowa'): '19021', ('Butler County', 'Iowa'): '19023', ('Calhoun County', 'Iowa'): '19025', ('Carroll County', 'Iowa'): '19027', ('Cass County', 'Iowa'): '19029', ('Cedar County', 'Iowa'): '19031', ('Cerro Gordo County', 'Iowa'): '19033', ('Cherokee County', 'Iowa'): '19035', ('Chickasaw County', 'Iowa'): '19037', ('Clarke County', 'Iowa'): '19039', ('Clay County', 'Iowa'): '19041', ('Clayton County', 'Iowa'): '19043', ('Clinton County', 'Iowa'): '19045', ('Crawford County', 'Iowa'): '19047', ('Dallas County', 'Iowa'): '19049', ('Davis County', 'Iowa'): '19051', ('Decatur County', 'Iowa'): '19053', ('Delaware County', 'Iowa'): '19055', ('Des Moines County', 'Iowa'): '19057', ('Dickinson County', 'Iowa'): '19059', ('Dubuque County', 'Iowa'): '19061', ('Emmet County', 'Iowa'): '19063', ('Fayette County', 'Iowa'): '19065', ('Floyd County', 'Iowa'): '19067', ('Franklin County', 'Iowa'): '19069', ('Fremont  ...

# %%
dateToDictOf_CountyToAnomalyScore = {}
with open('../data/processed/AnomaliesTimespreadByIsoForest.csv') as csv_file1:
    currentDate_CountyToAnomalyScore = {}
    currentDate = -1
    
    csv_reader = csv.reader(csv_file1, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            if currentDate == -1:
                currentDate = row[0]
                
            if currentDate != row[0]:
                dateToDictOf_CountyToAnomalyScore[currentDate] = currentDate_CountyToAnomalyScore
                currentDate_CountyToAnomalyScore = {}
                currentDate = row[0]
            
            #if row[1] in countyToFips:
            county = row[1]
            state = row[2]
            if county == "New York City County":
                county = "New York County"
            if county != "Unknown County":
                currentDate_CountyToAnomalyScore[countyAndState_ToFips[(county, state)]] = row[8]

            line_count += 1
    print(f'Processed {line_count} lines.')
print(dateToDictOf_CountyToAnomalyScore)
# Out:
# Column names are date, county, state, pop, cases, deaths, casesPerCapita, deathsPerCapita, scores, anomaly
955', '34003': '-0.02777209495306543', '55079': '-0.007982920743830446', '53033': '-0.09547096041779712', '12019': '-0.024529291398041053', '17031': '-0.009569057742734421', '9001': '-0.011158417486991867', '6037': '-0.006927283264391293', '6085': '-0.08091022387447566', '25025': '-0.0872866154836518', '22071': '-0.059244269288293294'}, '43914': {'36103': '-0.12390601839767035', '36119': '-0.0005149436468373514', '36061': '-0.06100620728997186', '34003': '-0.032057930648796584', '53033': '-0.11083428865140477', '45085': '-0.00206186666133068', '13273': '-0.0910113787300959', '17031': '-0.012455318648984748', '6037': '-0.0219304362822752', '6085': '-0.10437102703111811', '25025': '-0.0910113787300959', '22071': '-0.08126962001936655', '18097': '-0.03313157574201764'}, '43915': {'34003': '-0.031951094031841154', '36061': '-0 ...

# %%
fileNumber = 0
for cDate, cDictOfCountyToAnomalyScore in dateToDictOf_CountyToAnomalyScore.items():
    outputFile = '../data/processed/AnomalyAnimationData/iso' + str(fileNumber) + '.csv'
    if path.exists(outputFile):
        os.remove(outputFile)
    with open(outputFile, 'a', newline='') as lof_file:
        fieldnames = ['fips', 'anomalyScore']
        writer = csv.DictWriter(lof_file, fieldnames=fieldnames)
        myHeaderRowData = {}
        for colName in fieldnames:
            myHeaderRowData[colName] = colName
        writer.writerow(myHeaderRowData)



        rowN = 0
        for cCountyAndState, cFips in countyAndState_ToFips.items():
            rowN = rowN + 1
            myRowData = {}
            if cFips in cDictOfCountyToAnomalyScore:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = cDictOfCountyToAnomalyScore[cFips]
            else:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = 0
            writer.writerow(myRowData)
        #print(rowN)
    fileNumber = fileNumber + 1

# %%
start_date = datetime.datetime(2020, 2, 29)
curr_date = start_date
# iterate through all anomaly date data

if not os.path.exists("../data/processed/AnomalyAnimationImages"):
    os.mkdir("../data/processed/AnomalyAnimationImages")

for i in range(0, 248):
    curr_date = start_date + datetime.timedelta(days=i)

    # place the date of the data as the figure name
    filename = curr_date.strftime("../data/processed/AnomalyAnimationImages/%m-%d-%Y.png")
    if not os.path.exists(filename):
        df = pd.read_csv("../data/processed/AnomalyAnimationData/iso" + str(i) + ".csv",
                           dtype={"fips": str})

        df = df.sort_values(by=['fips'])


        fig = px.choropleth_mapbox(df, geojson=counties, locations='fips', color='anomalyScore',
                                   color_continuous_scale="Viridis",
                                   range_color=(df["anomalyScore"].min(), 0),
                                   mapbox_style="carto-positron",
                                   zoom=2.8, center = {"lat": 37.0902, "lon": -95.7129},
                                   opacity=0.5,
                                   labels={'anomalyScore':'Anomaly Score'}
                                  )
        fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
        print(filename)
        fig.write_image(filename)

# %%
# Out:
# 3143

# %%
# Out:
# -0.10162013390758806

# %%
dateToDictOf_CountyToAnomalyScore = {}
with open('../data/processed/CasesAnomaliesTimespreadByIsoForest.csv') as csv_file1:
    currentDate_CountyToAnomalyScore = {}
    currentDate = -1
    
    csv_reader = csv.reader(csv_file1, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            if currentDate == -1:
                currentDate = row[0]
                
            if currentDate != row[0]:
                dateToDictOf_CountyToAnomalyScore[currentDate] = currentDate_CountyToAnomalyScore
                currentDate_CountyToAnomalyScore = {}
                currentDate = row[0]
            
            #if row[1] in countyToFips:
            county = row[1]
            state = row[2]
            if county == "New York City County":
                county = "New York County"
            if county != "Unknown County":
                currentDate_CountyToAnomalyScore[countyAndState_ToFips[(county, state)]] = row[8]

            line_count += 1
    print(f'Processed {line_count} lines.')
print(dateToDictOf_CountyToAnomalyScore)
# Out:
# Column names are date, county, state, pop, cases, deaths, casesPerCapita, deathsPerCapita, scores, anomaly
# Processed 6921 lines.
# {'43855': {'53061': '-0.0035191936044266514'}, '43856': {'53061': '-0.005257503781996742'}, '43857': {'53061': '-0.004393886931044477'}, '43858': {'53061': '-0.00408942172816229'}, '43859': {'53061': '-0.004739323733153555'}, '43860': {'17031': '-0.0026264351704160527'}, '43861': {'6085': '-0.0026418670404732003'}, '43862': {'25025': '-0.013511213987472348'}, '43863': {'25025': '-0.011597729074010465'}, '43864': {'25025': '-0.013370176254775323'}, '43865': {'25025': '-0.012482442673526939'}, '43866': {'25025': '-0.013470785438646549'}, '43867': {'25025': '-0.014264531762015364'}, '43868': {'25025': '-0.013296106886282466'}, '43869': {'25025': '-0.012722483407434315'}, '43870': {'25025': '-0.013675563619714004'}, '43871': {'25025': '-0.015260879700349395'}, '43872': {'25025': '-0.014570269760734278'}, '43873': {'25025': '-0.015292041087638819'}, '43874': {'25025': '-0.017706659282733517'}, '43875': {'25025': '-0.017889252203853068'}, '43876': {'25025': '-0.016454194777143716'}, '43877': {'25025': '-0.01431480761070636'}, '43878': {'25025': '-0.01875208887110069'}, '43879': {'25025': '-0.015023392650392653'}, '43880': {'25025': '-0.017206673001191164'}, '43881': {'25025': '-0.018221244080103283'}, '43882': {'25025': '-0.020075195606819363'}, '43883': {'25025': '-0.018071453974962237'}, '43884': {'25025': '-0.021149936118809887'}, '43885': {'25025': '-0.0181122489603891'}, '43886': {'25025': '-0.019358595665672995'}, '43887': {'25025': '-0.024904224115635865'}, '43888': {'25025': '-0.02509343235774708'}, '43889': {'25025': '-0.014538964857895409'}, '43890': {'25025': '-0.0005844661531705375'}, '43891': {'6085': '-0.03567241745704042'}, '43892': {'6085': '-0.05152644238456028'}, '43893': {'6085': '-0.05567636946338561'}, '43894': {'6085': '-0.0570089131084941'}, '43895': {'6085': '-0.0627247867242886'}, '43896': {'6085': '-0.01626569033870262'}, '43897': {'36119': '-0.05309378067268833'}, '43898': {'36119': '-0.0635664227372642', '53033': '-0.005007185266577396'}, '43899': {'36119': '-0.08960477975263959', '53033': '-0.003768050314806648'}, '43900': {'36119': '-0.02296333251685101', '25025': '-0.04745206265688007'}, '43901': {'36119': '-0.030618260078517756', '25025': '-0.03354242752670833'}, '43902': {'36119': '-0.045852550192931996', '53033': '-0.021532068057462328', '6085': '-0.0064310316930139555'}, '43903': {'36103': '-0.055085482837168964', '53033': '-0.022701582007388477', '6085': '-0.01615866485995221', '25025': '-3.190569949818034e-05'}, '43904': {'36119': '-0.008175892753592984', '36103': '-0.06896766096348494', '53033': '-0.001628547260043911'}, '43905': {'36119': '-0.021459382950215655', '36103': '-0.06658214260439044', '53033': '-0.010962136136768441', '6085': '-0.02424431806450944', '25025': '-0.019792938473974453'}, '43906': {'36119': '-0.034978150233799354', '36103': '-0.09552774131617459', '53033': '-0.02667403335437235', '6085': '-0.03220074192579003', '25025': '-0.05525527754997106'}, '43907': {'36119': '-0.11174656323451915', '36103': '-0.12886719854999196', '53033': '-0.04706716315758297', '49043': '-0.0008630233679592925', '6085': '-0.07177891680622728', '25025': '-0.08244079399544924'}, '43908': {'36119': '-0.09144035501408088', '36103': '-0.11395818716581574', '49043': '-0.008526453482817109', '53033': '-0.032147515956986505', '6085': '-0.05256227254603896', '25025': '-0.07006441756809734', '22071': '-0.00010983411785003838'}, '43909': {'36103': '-0.13949901875892456', '36119': '-0.12988237087535215', '49043': '-0.005116453909908225', '53033': '-0.04353398975430156', '6085': '-0.06540342549508793', '25025': '-0.09473305719335401'}, '43910': {'36119': '-0.0988146628086023', '36103': '-0.11451602829172614', '36061': '-0.013971307874799499', '53033': '-0.03702769532497374', '49043': '-0.014512689728022554', '6085': '-0.04598486406325042', '25025': '-0.0757744781143781', '22071': '-0.007046159639791605', '17031': '-0.017768684258478884'}, '43911': {'36103': '-0.12894136953920843', '36119': '-0.10664967376028467 ...

# %%
fileNumber = 0
for cDate, cDictOfCountyToAnomalyScore in dateToDictOf_CountyToAnomalyScore.items():
    outputFile = '../data/processed/AnomalyAnimationData/CasesIso' + str(fileNumber) + '.csv'
    if path.exists(outputFile):
        os.remove(outputFile)
    with open(outputFile, 'a', newline='') as lof_file:
        fieldnames = ['fips', 'anomalyScore']
        writer = csv.DictWriter(lof_file, fieldnames=fieldnames)
        myHeaderRowData = {}
        for colName in fieldnames:
            myHeaderRowData[colName] = colName
        writer.writerow(myHeaderRowData)



        rowN = 0
        for cCountyAndState, cFips in countyAndState_ToFips.items():
            rowN = rowN + 1
            myRowData = {}
            if cFips in cDictOfCountyToAnomalyScore:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = cDictOfCountyToAnomalyScore[cFips]
            else:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = 0
            writer.writerow(myRowData)
        #print(rowN)
    fileNumber = fileNumber + 1

# %%
start_date = datetime.datetime(2020, 2, 29)
curr_date = start_date
# iterate through all anomaly date data
for i in range(0, 248):
    curr_date = start_date + datetime.timedelta(days=i)
    df = pd.read_csv("../data/processed/AnomalyAnimationData/CasesIso" + str(i) + ".csv",
                       dtype={"fips": str})

    df = df.sort_values(by=['fips'])


    fig = px.choropleth_mapbox(df, geojson=counties, locations='fips', color='anomalyScore',
                               color_continuous_scale="Viridis",
                               range_color=(df["anomalyScore"].min(), 0),
                               mapbox_style="carto-positron",
                               zoom=2.8, center = {"lat": 37.0902, "lon": -95.7129},
                               opacity=0.5,
                               labels={'anomalyScore':'Anomaly Score'}
                              )
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    if not os.path.exists("../data/processed/CasesIsoAnomalyAnimationImages"):
        os.mkdir("../data/processed/CasesIsoAnomalyAnimationImages")
    # place the date of the data as the figure name
    filename = curr_date.strftime("../data/processed/CasesIsoAnomalyAnimationImages/%m-%d-%Y.png")
    if not os.path.exists(filename):
        print(filename)
        fig.write_image(filename)
# Out:
# ../data/processed/CasesIsoAnomalyAnimationImages/02-29-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-01-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-02-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-03-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-04-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-05-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-06-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-07-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-08-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-09-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-10-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-11-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-12-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-13-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-14-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-15-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-16-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-17-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-18-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-19-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-20-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-21-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-22-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-23-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-24-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-25-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-26-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-27-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/03-28-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/11-01-2020.png
# ../data/processed/CasesIsoAnomalyAnimationImages/11-02-2020.png

# %%
dateToDictOf_CountyToAnomalyScore = {}
with open('../data/processed/AnomaliesTimespreadByLocalOutlier.csv') as csv_file1:
    currentDate_CountyToAnomalyScore = {}
    currentDate = -1
    
    csv_reader = csv.reader(csv_file1, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            if currentDate == -1:
                currentDate = row[0]
                
            if currentDate != row[0]:
                dateToDictOf_CountyToAnomalyScore[currentDate] = currentDate_CountyToAnomalyScore
                currentDate_CountyToAnomalyScore = {}
                currentDate = row[0]
            
            #if row[1] in countyToFips:
            county = row[1]
            state = row[2]
            if county == "New York City County":
                county = "New York County"
            if county != "Unknown County":
                currentDate_CountyToAnomalyScore[countyAndState_ToFips[(county, state)]] = row[8]

            line_count += 1
    print(f'Processed {line_count} lines.')
print(dateToDictOf_CountyToAnomalyScore)
# Out:
# Column names are date, county, state, pop, cases, deaths, casesPerCapita, deathsPerCapita, scores, anomaly
# Processed 1 lines.
# {}

# %%
fileNumber = 0
for cDate, cDictOfCountyToAnomalyScore in dateToDictOf_CountyToAnomalyScore.items():
    outputFile = '../data/processed/AnomalyAnimationData/LOF' + str(fileNumber) + '.csv'
    if path.exists(outputFile):
        os.remove(outputFile)
    with open(outputFile, 'a', newline='') as lof_file:
        fieldnames = ['fips', 'anomalyScore']
        writer = csv.DictWriter(lof_file, fieldnames=fieldnames)
        myHeaderRowData = {}
        for colName in fieldnames:
            myHeaderRowData[colName] = colName
        writer.writerow(myHeaderRowData)



        rowN = 0
        for cCountyAndState, cFips in countyAndState_ToFips.items():
            rowN = rowN + 1
            myRowData = {}
            if cFips in cDictOfCountyToAnomalyScore:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = cDictOfCountyToAnomalyScore[cFips]
            else:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = 0
            writer.writerow(myRowData)
        #print(rowN)
    fileNumber = fileNumber + 1

# %%
start_date = datetime.datetime(2020, 2, 29)
curr_date = start_date
# iterate through all anomaly date data
for i in range(0, 248):
    curr_date = start_date + datetime.timedelta(days=i)
    df = pd.read_csv("../data/processed/AnomalyAnimationData/LOF" + str(i) + ".csv",
                       dtype={"fips": str})

    df = df.sort_values(by=['fips'])


    fig = px.choropleth_mapbox(df, geojson=counties, locations='fips', color='anomalyScore',
                               color_continuous_scale="Viridis",
                               range_color=(df["anomalyScore"].min(), 0),
                               mapbox_style="carto-positron",
                               zoom=2.8, center = {"lat": 37.0902, "lon": -95.7129},
                               opacity=0.5,
                               labels={'anomalyScore':'Anomaly Score'}
                              )
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    if not os.path.exists("../data/processed/LOFAnomalyAnimationImages"):
        os.mkdir("../data/processed/LOFAnomalyAnimationImages")
    # place the date of the data as the figure name
    filename = curr_date.strftime("../data/processed/LOFAnomalyAnimationImages/%m-%d-%Y.png")
    if not os.path.exists(filename):
        print(filename)
        fig.write_image(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-d4b1c9d525d8> in <module>
#       4 for i in range(0, 248):
#       5     curr_date = start_date + datetime.timedelta(days=i)
# ----> 6     df = pd.read_csv("../data/processed/AnomalyAnimationData/LOF" + str(i) + ".csv",
#       7                        dtype={"fips": str})
#       8
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../data/processed/AnomalyAnimationData/LOF0.csv does not exist: '../data/processed/AnomalyAnimationData/LOF0.csv'

# %%
dateToDictOf_CountyToAnomalyScore = {}
with open('../data/processed/CasesAnomaliesTimespreadByLocalOutlier.csv') as csv_file1:
    currentDate_CountyToAnomalyScore = {}
    currentDate = -1
    
    csv_reader = csv.reader(csv_file1, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            if currentDate == -1:
                currentDate = row[0]
'-0.09485579466517857'}, '43954': {'36103': '-0.10839745073289331', '36119': '-0.0041714420118385', '25025': '-0.09485579466517857'}, '43955': {'36103': '-0.10839745073289331', '36119': '-0.005217835217106281', '25025': '-0.09485579466517857'}, '43956': {'36103': '-0.10839745073289331', '36119': '-0.005217835217106281', '25025': '-0.09485579466517857'}, '43957': {'36103': '-0.10839745073289331', '36119': '-0.005217835217106281', '25025': '-0.09485579466517857'}, '43958': {'36103': '-0.10839745073289331', '36119': '-0.005217835217106281', '25025': '-0.09485579466517857'}, '43959': {'36103': '-0.10899101209397954', '36119': '-0.005217835217106281', '25025': '-0.0960249825168793'}, '43960': {'36103': '-0.10899101209397954', '36119': '-0.00469446162064846', '25025': '-0.0960249825168793'}, '43961': {'36103': '-0.10899101209397954', '36119': '-0.00469446162064846', '17031': '-0.003126463799635548', '25025': '-0.0960249825168793'}, '43962': {'36103': '-0.10899101209397954', '36119': '-0.00469446162064846', '17031': '-0.002604504717883871', '25025': '-0.0960249825168793'}, '43963': {'36103': '-0.10899101209397954', '36119': '-0.00469446162064846', '17031': '-0.0041714420118385', '25025': '-0.0960249825168793'}, '43964': {'36103': '-0.10899101209397954', '36119': '-0.00469446162064846', '17031': '-0.005217835217106281', '25025': '-0.0960249825168793'}, '43965': {'36103': '-0.10899101209397954', '36119': '-0.007314874273534722', '17031': '-0.00469446162064846', '25025': '-0.09 ...

# %%
fileNumber = 0
for cDate, cDictOfCountyToAnomalyScore in dateToDictOf_CountyToAnomalyScore.items():
    outputFile = '../data/processed/AnomalyAnimationData/CasesLOF' + str(fileNumber) + '.csv'
    if path.exists(outputFile):
        os.remove(outputFile)
    with open(outputFile, 'a', newline='') as lof_file:
        fieldnames = ['fips', 'anomalyScore']
        writer = csv.DictWriter(lof_file, fieldnames=fieldnames)
        myHeaderRowData = {}
        for colName in fieldnames:
            myHeaderRowData[colName] = colName
        writer.writerow(myHeaderRowData)



        rowN = 0
        for cCountyAndState, cFips in countyAndState_ToFips.items():
            rowN = rowN + 1
            myRowData = {}
            if cFips in cDictOfCountyToAnomalyScore:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = cDictOfCountyToAnomalyScore[cFips]
            else:
                if len(cFips) == 4:
                    myRowData['fips'] = "0" + str(cFips)
                else:
                    myRowData['fips'] = cFips
                myRowData['anomalyScore'] = 0
            writer.writerow(myRowData)
        #print(rowN)
    fileNumber = fileNumber + 1

# %%
start_date = datetime.datetime(2020, 2, 29)
curr_date = start_date
# iterate through all anomaly date data
for i in range(0, 248):
    curr_date = start_date + datetime.timedelta(days=i)
    df = pd.read_csv("../data/processed/AnomalyAnimationData/CasesLOF" + str(i) + ".csv",
                       dtype={"fips": str})

    df = df.sort_values(by=['fips'])


    fig = px.choropleth_mapbox(df, geojson=counties, locations='fips', color='anomalyScore',
                               color_continuous_scale="Viridis",
                               range_color=(df["anomalyScore"].min(), 0),
                               mapbox_style="carto-positron",
                               zoom=2.8, center = {"lat": 37.0902, "lon": -95.7129},
                               opacity=0.5,
                               labels={'anomalyScore':'Anomaly Score'}
                              )
    fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
    if not os.path.exists("../data/processed/CasesLOFAnomalyAnimationImages"):
        os.mkdir("../data/processed/CasesLOFAnomalyAnimationImages")
    # place the date of the data as the figure name
    filename = curr_date.strftime("../data/processed/CasesLOFAnomalyAnimationImages/%m-%d-%Y.png")
    if not os.path.exists(filename):
        print(filename)
        fig.write_image(filename)
# Out:
# ../data/processed/CasesLOFAnomalyAnimationImages/09-10-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-11-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-12-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-13-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-14-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-15-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-16-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-17-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-18-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-19-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-20-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-21-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-22-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-23-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-24-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-25-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-26-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-27-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-28-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-29-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/09-30-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/10-01-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/10-02-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/10-03-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/10-04-2020.png
# ../data/processed/CasesLOFAnomalyAnimationImages/10-05-2020.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-23543569e613> in <module>
#       4 for i in range(0, 248):
#       5     curr_date = start_date + datetime.timedelta(days=i)
# ----> 6     df = pd.read_csv("../data/processed/AnomalyAnimationData/CasesLOF" + str(i) + ".csv",
#       7                        dtype={"fips": str})
#       8
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../data/processed/AnomalyAnimationData/CasesLOF220.csv does not exist: '../data/processed/AnomalyAnimationData/CasesLOF220.csv'

# %% [markdown]
# # Generate GIFS for each analysis

# %%
import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')
from urllib.request import urlopen
import os
import json
import pandas as pd
import numpy as np
import plotly.express as px
#from fbprophet import Prophet
import os.path
import datetime 

with open('../data/raw/geojson-counties-fips.json') as json_file:
    counties = json.load(json_file)
    
    
# initialize large dataframe, start date and current date
start_date = datetime.datetime(2020, 2, 29)
curr_date  = start_date

df         = pd.read_csv("../data/processed/AnomalyAnimationData/CasesIso0.csv", dtype={"fips": str})
df['date'] = start_date
df['date'] = pd.to_datetime(df['date'])

#iterate across all Iso case csvs and append data to large dataframe
for i in range(1, 248):
    curr_date = start_date + datetime.timedelta(days=i)
    curr_iso_df = pd.read_csv("../data/processed/AnomalyAnimationData/CasesIso" + str(i) + ".csv", dtype={"fips": str})
    curr_iso_df['date'] = curr_date
    curr_iso_df['date'] = pd.to_datetime(df['date'])
    df = df.append(curr_iso_df, ignore_index=True)

print(len(df))
df.to_csv('../data/processed/anomalyIsoForestTimeSpread.csv', index=False)

# Generate GIF 
# fig = px.choropleth(df, geojson=counties, locations='fips', color='anomalyScore',
#        color_continuous_scale="thermal",
#        animation_frame='anomalyScore',
#        range_color=(-2, 0),
#        scope="usa",
#        labels={'cases':'cases'}
#        )

# fig.write_html("iso_forest_anomalies_timespread.html")
# Out:
# 779464
